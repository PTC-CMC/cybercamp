# %% [markdown]
# # Speeding things up: Neighborlists and Dangerous Builds
#
#
# ### Cutoffs
# Recall that we typically apply a cutoff to pair potentials once the numerical value of the pair potential becomes very small. E.g., in our prior example of the Lennard-Jones potential:
#
#
# $U(r) = 4\epsilon\left[ \left(\frac{\sigma}{r}\right)^{12}- \left(\frac{\sigma}{r}\right)^6 \right],  r < r_c$
# $U(r) = 0 r,  \ge r_c$
#
# Where $r_c$ is often $2.5\sigma$.
#
# By cutting off the interaction, we avoid having to calculate the energy/force between pair of atoms beyond the cutoff.  However, even though we avoid calculating the energy with these atoms, we still have to determine the separation between them to know if they are beyond the cutoff.  This distance calculation is itself quite costly (since we calculate r from the cartesian coordinates) and apply to an entire system scales as $O(N^2)$, where $N$ is the number of particles.
#
# As an example, the python code below compare the number of interactions that would be calculated with and without a cutoff.

# %%
import numpy
import random
import math 

n_particles = 1000
cutoff = 2.5
cutoff2 = cutoff*cutoff

xyz = numpy.zeros((n_particles,3))
L = numpy.array([10.0,10.0,10.0])
invL = numpy.array([1.0/L[0],1.0/L[1],1.0/L[2]])


def init_particles():
    #set a seed so every run uses the same particle array for consistency
    random.seed(12345)
    
    for i in range(0,n_particles):
        #generate coordinates in a box of dimension L[0]*L[1]*L[2]
        #note particles are free to overlap, this is simply for comparison
        xyz[i][0] = L[0]*random.random()
        xyz[i][1] = L[1]*random.random()
        xyz[i][2] = L[2]*random.random()

#very naive loop over particles
def simple_loop():
    sum_energy = 0
    counter_total = 0
    counter_cutoff = 0

    for i in range (0, n_particles):
        for j in range(i, n_particles):
            dx = xyz[i][0]-xyz[j][0]
            dy = xyz[i][1]-xyz[j][1]
            dz = xyz[i][2]-xyz[j][2]

            #apply pbc
            dx = dx-L[0]*round(dx*invL[0])
            dy = dy-L[1]*round(dy*invL[1])
            dz = dz-L[2]*round(dz*invL[2])
            
            r2 = dx*dx+dy*dy+dz*dz
            counter_total = counter_total+1
            if r2 < cutoff2:
                counter_cutoff = counter_cutoff +1
                
    print("number of energy calculations with no cutoff: ", counter_total)
    print("number of energy calculations with with cutoff: ", counter_cutoff)
      
init_particles()
simple_loop()
# Out:
# number of energy calculations with no cutoff:  500500
# number of energy calculations with with cutoff:  33879

# %% [markdown]
# ### Simple, brute force neighborlist
# Recall that, to avoid having to perform this distance calculation every timesteps, a neighborlist can instead be constructed that includes all particles within the cutoff + buffer (the buffer is often called the "skin"). The general idea is that the local environment of a particle changes rather slowly, and thus the same neighborlist can be applied multiple times before needing to be reconstructed, thus reducing the computation. The construction of the neighborlist is still $O(N^2)$ (i.e., it's often called "brute force"), but it is done less frequently thus providing speed improvement.
#
#
# ### Cell list-based neighborlist
# To improve upon the brute force neighborlist, a cell list can first be constructed, and this cell list used to generate the neighborlist.  A cell list is constructed by gridding the system up into smaller boxes, where each edge length is typically $\ge r_c+buffer$.  Cell lists can be constructed relatively inexpensively by binning particles in each direction. The neighborlist is then constructed for a given particle by looping over the cell it is in and it's neighbor cells (note, since pair potentials are pair-wise additive, we only need to consider half of the cells; that is, if A is a neighbor of B, then B is a neighbor of A).
#
# For efficiency, some codes allow multiple cell lists in a system; this can be especially useful if your system has interactions/particle sizes that are very different; if a single neighborlist were used, it would need to be based on the largest interaction cutoff, thus negating speed increases for particles with shorter range interactions.
#
#
# Recall that the frequency of reconstruction (and hence the speed up) will depend on numerous factors:
#
# How fast  the system is changing.
# > This is often a consequence of the phase, where, for example gas phases will change much more rapidly than dense fluids.  Similarly, temperature will play a role, where high temperature systems will have particles moving faster than low temperature.
#
# The size of the buffer/skin.
# > If this is set too small, the neighborlist will need to be rebuilt very frequently, if too large, the computational savings will be minimal as the list will contain a very large number of particles.
# To speed things up, we can generate a neighborlist, which is a list of particles within our interaction cutoff (i.e., $r_c$) with some
#
#
# The neighborlist has two basic parameters: (1) the skin size (i.e, buffer) and (2) the frequency of updating/checking for updates. These two parameters are coupled; for example, a system with high mobility may require a larger skin to avoid needing to be updated the neighborlist every timestep and to ensure particle interactions are not missed.

# %% [markdown]
# ### The Skin
# The skin is used to create a buffer of particles that are close by, but just outside of the interaction cutoff. This increases the number of calculations that must be done, since we still need to calculate the distance with all particles in the neighborlist even if a particle is ultimately be outside of the interaction range. However, by including this buffer of particles, neighborlists need to be updated less frequently, since we are basically keeping track of the location of nearby particles that we may interact with in the near future.

# %% [markdown]
# ### Updating Frequency
#
# In most codes, you have two ways of enforcing an update of the neighborlist.
#
# For example, one approach is to specify that the neighborlist be updated every N steps. This approach tends to work well for systems that are dense or slowly moving, as particle motion should be relatively uniform in the system. However, this may make it challenging to balance wanting to reduce the number of updates that are done and ensuring that particles don't move too far, resulting in missed interactions (i.e., dangerous builds). This approach can speed things up, but should be considered "less safe".
#
# Another approach is to check the displacement of particles. The general rule is that a neighborlist needs to be rebuilt if any particle has move more than skin/2.0, such to ensure that particle interactions are not being missed. This helps to ensure that "dangerous builds" aren't present in the system (See below). In many codes this also can be couple "checking" with a time modulation, e.g., only check every N timesteps.

# %% [markdown]
# ### Dangerous Builds
#
# Most codes will output a summary of the total number of dangerous builds, that is, the total number of times it built the neighborlist was rebuilt with particles move greater than skin/2.0. In such cases, interactions may be missed, resulting in misleading and incorrect behavior.
#
# For example, the output from a simulation code may look something similar to:
#
# > -- Neighborlist stats:
# 6392 normal updates / 167 forced updates / 0 dangerous updates <br>
# n_neigh_min: 16 / n_neigh_max: 100 / n_neigh_avg: 64.63 <br>
# shortest rebuild period: 6<br>
#
# where it is clear that we did not have any dangerous builds. This also provides information regarding the minimum time between neighborlist updates. In more extreme cases of missed interactions, systems may crash due to particles moving outside the bounds of the simulation cell (usually due to extremely high forces on the particles).
#
# Often more detailed information can be acquired.  For example, 50% of the computational time is actually spent on the neighborlist.
#
# > `Simulation:     3.1s | 100.0%  `<br>
#   `      Integrate:     0.5s | 16.5% `<br>
#   `              NVT step 1:     0.1s | 4.2% `<br>
#   `              NVT step 2:     0.1s | 3.0% `<br>
#   `              Net force:      0.1s | 2.9% `<br>
#   `              Thermo:         0.1s | 3.7% `<br>
#   `              Self:           0.1s | 2.8% `<br>
#   `      Neighbor:      1.6s | 50.0% `<br>
#   `              Cell:           0.0s | 0.8% `<br>
#   `                      compute:     0.0s | 0.5% `<br>
#   `                      init:        0.0s | 0.2% `<br>
#   `              compute:        1.5s | 48.2% `<br>
#   `              dist-check:     0.0s | 1.0% `<br>
#   `      Pair lj:       0.9s | 30.2% `<br>
#   `      SFCPack:       0.1s | 3.1% `<br>
#   `      Self:          0.0s | 0.2% `<br>

# %% [markdown]
# ### Exercises
#
# 1) Using the simple monoatomic LJ system (shown below and similar to the Anatomy of a Script file), adjust the nlist parameters.
# - change the buffer (r_buff) to examine the performance as a function of increasing/decreasing the skin.  How small can you make the skin before dangerous builds are detected? How does this impact the speed of the code (e.g. TPS).
#
#  See: http://hoomd-blue.readthedocs.io/en/stable/module-md-nlist.html#hoomd.md.nlist.cell
#
# 2) What happens if you set the check period to 1? 10? 100? 1000? Can you speed up the simulation and still avoid dangerous builds?
#
# 3) What does the neightborlist auto-tuning function give you (note, you must define this after the integrate call)?
#
# 4) How does temperature (kT) influence the parameters you need and number of rebuilds?

# %%
#import hoomd
import hoomd.md
import hoomd.deprecated

hoomd.context.initialize("");
hoomd.init.create_lattice(unitcell=hoomd.lattice.sc(a=2), n=5)

nl = hoomd.md.nlist.cell(r_buff=0.5, dist_check=True, check_period=10)
lj = hoomd.md.pair.lj(r_cut=2.5, nlist=nl)
lj.pair_coeff.set('A', 'A', epsilon=1.0, sigma=1.0)

hoomd.md.integrate.mode_standard(dt=0.005)

all = hoomd.group.all();
hoomd.md.integrate.langevin(group=all, kT=1.0, seed=42)


hoomd.analyze.log(filename="log-output.log",
                  quantities=['potential_energy', 'temperature'],
                  period=100,
                  overwrite=True)
hoomd.dump.gsd("trajectory.gsd", period=2e3, group=all, overwrite=True)
hoomd.dump.dcd("trajectory.dcd", period=2e3, group=all, overwrite=True)

hoomd.run(1e4)
hoomd.deprecated.dump.xml(group=all, filename="snapshot.xml", vis=True)
# Out:
# notice(2): Group "all" created containing 125 particles
# notice(2): integrate.langevin/bd is using specified gamma values
# notice(2): -- Neighborlist exclusion statistics -- :
# notice(2): Particles with 0 exclusions             : 125
# notice(2): Neighbors included by diameter          : no
# notice(2): Neighbors excluded when in the same body: no
# ** starting run **
# Time 00:00:08 | Step 200000 / 200000 | TPS 23759.3 | ETA 00:00:00
# Average TPS: 23757.7
# ---------
# -- Neighborlist stats:
# 12615 normal updates / 2000 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 19 / n_neigh_avg: 7.928
# shortest rebuild period: 10
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 9 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:09 | Step 205000 / 205000 | TPS 8029.79 | ETA 00:00:00
# Average TPS: 8017.33
# ---------
# -- Neighborlist stats:
# 2450 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 16 / n_neigh_avg: 4.544
# shortest rebuild period: 2
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:10 | Step 210000 / 210000 | TPS 7912.93 | ETA 00:00:00
# Average TPS: 7902.44
# ---------
# -- Neighborlist stats:
# 2450 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 19 / n_neigh_avg: 5.472
# shortest rebuild period: 2
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:11 | Step 215000 / 215000 | TPS 8121.34 | ETA 00:00:00
# Average TPS: 8106.36
# ---------
# -- Neighborlist stats:
# 2454 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 18 / n_neigh_avg: 5.32
# shortest rebuild period: 1
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:11 | Step 220000 / 220000 | TPS 11330.4 | ETA 00:00:00
# Average TPS: 11298.6
# ---------
# -- Neighborlist stats:
# 1514 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 12 / n_neigh_avg: 4.944
# shortest rebuild period: 2
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 9 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:12 | Step 225000 / 225000 | TPS 11361.1 | ETA 00:00:00
# Average TPS: 11347.9
# ---------
# -- Neighborlist stats:
# 1529 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 13 / n_neigh_avg: 4.952
# shortest rebuild period: 3
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:12 | Step 230000 / 230000 | TPS 11219.5 | ETA 00:00:00
# Average TPS: 11182.3
# ---------
# -- Neighborlist stats:
# 1522 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 19 / n_neigh_avg: 5.304
# shortest rebuild period: 3
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 2 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:13 | Step 235000 / 235000 | TPS 13498.9 | ETA 00:00:00
# Average TPS: 13474.4
# ---------
# -- Neighborlist stats:
# 1037 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 18 / n_neigh_avg: 5.76
# shortest rebuild period: 3
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:13 | Step 240000 / 240000 | TPS 15130.8 | ETA 00:00:00
# Average TPS: 15089.8
# ---------
# -- Neighborlist stats:
# 1014 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 22 / n_neigh_avg: 6.416
# shortest rebuild period: 3
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 14 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:14 | Step 245000 / 245000 | TPS 14379.2 | ETA 00:00:00
# Average TPS: 14356.8
# ---------
# -- Neighborlist stats:
# 1045 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 15 / n_neigh_avg: 5.528
# shortest rebuild period: 3
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:14 | Step 250000 / 250000 | TPS 17048.4 | ETA 00:00:00
# Average TPS: 7112.57
# ---------
# -- Neighborlist stats:
# 779 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 20 / n_neigh_avg: 5.784
# shortest rebuild period: 4
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:15 | Step 255000 / 255000 | TPS 17059.5 | ETA 00:00:00
# Average TPS: 16993.9
# ---------
# -- Neighborlist stats:
# 796 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 14 / n_neigh_avg: 5.496
# shortest rebuild period: 5
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 8 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:15 | Step 260000 / 260000 | TPS 16852.4 | ETA 00:00:00
# Average TPS: 16812.1
# ---------
# -- Neighborlist stats:
# 790 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 19 / n_neigh_avg: 6.248
# shortest rebuild period: 4
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:16 | Step 265000 / 265000 | TPS 19142.3 | ETA 00:00:00
# Average TPS: 19069.7
# ---------
# -- Neighborlist stats:
# 624 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 21 / n_neigh_avg: 6.288
# shortest rebuild period: 6
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 12 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:16 | Step 270000 / 270000 | TPS 19002.2 | ETA 00:00:00
# Average TPS: 18933.5
# ---------
# -- Neighborlist stats:
# 637 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 17 / n_neigh_avg: 6.272
# shortest rebuild period: 6
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 9 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:16 | Step 275000 / 275000 | TPS 18437.5 | ETA 00:00:00
# Average TPS: 18346
# ---------
# -- Neighborlist stats:
# 644 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 17 / n_neigh_avg: 6.592
# shortest rebuild period: 5
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:17 | Step 280000 / 280000 | TPS 20423 | ETA 00:00:00
# Average TPS: 20341.1
# ---------
# -- Neighborlist stats:
# 531 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 20 / n_neigh_avg: 7.184
# shortest rebuild period: 7
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:17 | Step 285000 / 285000 | TPS 21569.5 | ETA 00:00:00
# Average TPS: 21485.6
# ---------
# -- Neighborlist stats:
# 533 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 22 / n_neigh_avg: 6.824
# shortest rebuild period: 6
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:18 | Step 290000 / 290000 | TPS 21043.7 | ETA 00:00:00
# Average TPS: 20984
# ---------
# -- Neighborlist stats:
# 535 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 21 / n_neigh_avg: 6.824
# shortest rebuild period: 7
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:18 | Step 295000 / 295000 | TPS 20139.3 | ETA 00:00:00
# Average TPS: 20023.9
# ---------
# -- Neighborlist stats:
# 451 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 18 / n_neigh_avg: 6.952
# shortest rebuild period: 8
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:18 | Step 300000 / 300000 | TPS 22751.6 | ETA 00:00:00
# Average TPS: 22664.6
# ---------
# -- Neighborlist stats:
# 452 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 20 / n_neigh_avg: 7.152
# shortest rebuild period: 8
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:19 | Step 305000 / 305000 | TPS 23027.4 | ETA 00:00:00
# Average TPS: 22910.9
# ---------
# -- Neighborlist stats:
# 450 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 17 / n_neigh_avg: 6.304
# shortest rebuild period: 8
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 2 / n_max: 9 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:19 | Step 310000 / 310000 | TPS 21988.9 | ETA 00:00:00
# Average TPS: 21906.3
# ---------
# -- Neighborlist stats:
# 397 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 21 / n_neigh_avg: 7.28
# shortest rebuild period: 9
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 15 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:19 | Step 315000 / 315000 | TPS 22862.9 | ETA 00:00:00
# Average TPS: 22751.6
# ---------
# -- Neighborlist stats:
# 403 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 24 / n_neigh_avg: 7.368
# shortest rebuild period: 8
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 12 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:20 | Step 320000 / 320000 | TPS 18499.5 | ETA 00:00:00
# Average TPS: 18427.3
# ---------
# -- Neighborlist stats:
# 402 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 20 / n_neigh_avg: 7.464
# shortest rebuild period: 9
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 12 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:20 | Step 325000 / 325000 | TPS 18139.4 | ETA 00:00:00
# Average TPS: 18085.5
# ---------
# -- Neighborlist stats:
# 346 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 18 / n_neigh_avg: 6.56
# shortest rebuild period: 10
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 8 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:21 | Step 330000 / 330000 | TPS 18478.5 | ETA 00:00:00
# Average TPS: 18410.3
# ---------
# -- Neighborlist stats:
# 364 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 21 / n_neigh_avg: 7.784
# shortest rebuild period: 9
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 12 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:21 | Step 335000 / 335000 | TPS 20412.3 | ETA 00:00:00
# Average TPS: 20377.3
# ---------
# -- Neighborlist stats:
# 357 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 19 / n_neigh_avg: 7.392
# shortest rebuild period: 9
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:22 | Step 340000 / 340000 | TPS 23962.3 | ETA 00:00:00
# Average TPS: 23812.1
# ---------
# -- Neighborlist stats:
# 320 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 22 / n_neigh_avg: 7.76
# shortest rebuild period: 10
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:22 | Step 345000 / 345000 | TPS 24523 | ETA 00:00:00
# Average TPS: 24406.2
# ---------
# -- Neighborlist stats:
# 321 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 26 / n_neigh_avg: 8.856
# shortest rebuild period: 10
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:22 | Step 350000 / 350000 | TPS 24128.4 | ETA 00:00:00
# Average TPS: 24010.8
# ---------
# -- Neighborlist stats:
# 307 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 23 / n_neigh_avg: 7.608
# shortest rebuild period: 12
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 12 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:23 | Step 355000 / 355000 | TPS 24862.1 | ETA 00:00:00
# Average TPS: 8358.05
# ---------
# -- Neighborlist stats:
# 280 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 25 / n_neigh_avg: 8.328
# shortest rebuild period: 13
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:23 | Step 360000 / 360000 | TPS 24353.3 | ETA 00:00:00
# Average TPS: 24258.7
# ---------
# -- Neighborlist stats:
# 282 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 25 / n_neigh_avg: 8.296
# shortest rebuild period: 13
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:23 | Step 365000 / 365000 | TPS 24123.8 | ETA 00:00:00
# Average TPS: 23950.4
# ---------
# -- Neighborlist stats:
# 281 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 28 / n_neigh_avg: 8.656
# shortest rebuild period: 12
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 12 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:24 | Step 370000 / 370000 | TPS 23781.4 | ETA 00:00:00
# Average TPS: 23638.2
# ---------
# -- Neighborlist stats:
# 259 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 22 / n_neigh_avg: 8.288
# shortest rebuild period: 13
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:24 | Step 375000 / 375000 | TPS 25466.3 | ETA 00:00:00
# Average TPS: 25316.6
# ---------
# -- Neighborlist stats:
# 257 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 21 / n_neigh_avg: 8.504
# shortest rebuild period: 13
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:24 | Step 380000 / 380000 | TPS 24829.4 | ETA 00:00:00
# Average TPS: 24717.1
# ---------
# -- Neighborlist stats:
# 252 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 22 / n_neigh_avg: 8.296
# shortest rebuild period: 12
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 9 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:25 | Step 385000 / 385000 | TPS 25115.4 | ETA 00:00:00
# Average TPS: 24990.3
# ---------
# -- Neighborlist stats:
# 237 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 26 / n_neigh_avg: 9.712
# shortest rebuild period: 14
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:25 | Step 390000 / 390000 | TPS 24634.3 | ETA 00:00:00
# Average TPS: 24547.5
# ---------
# -- Neighborlist stats:
# 241 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 25 / n_neigh_avg: 8.768
# shortest rebuild period: 13
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 9 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:26 | Step 395000 / 395000 | TPS 25136.7 | ETA 00:00:00
# Average TPS: 25031.5
# ---------
# -- Neighborlist stats:
# 239 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 22 / n_neigh_avg: 8.344
# shortest rebuild period: 14
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:26 | Step 400000 / 400000 | TPS 23951.4 | ETA 00:00:00
# Average TPS: 23802.5
# ---------
# -- Neighborlist stats:
# 216 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 21 / n_neigh_avg: 8.88
# shortest rebuild period: 13
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:26 | Step 405000 / 405000 | TPS 19654.8 | ETA 00:00:00
# Average TPS: 19603.5
# ---------
# -- Neighborlist stats:
# 212 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 27 / n_neigh_avg: 9.248
# shortest rebuild period: 15
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:28 | Step 410000 / 410000 | TPS 16796.4 | ETA 00:00:00
# Average TPS: 16731
# ---------
# -- Neighborlist stats:
# 211 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 25 / n_neigh_avg: 9.648
# shortest rebuild period: 15
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 9 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:28 | Step 415000 / 415000 | TPS 18328.3 | ETA 00:00:00
# Average TPS: 18216.7
# ---------
# -- Neighborlist stats:
# 205 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 27 / n_neigh_avg: 10.056
# shortest rebuild period: 17
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:28 | Step 420000 / 420000 | TPS 17880.4 | ETA 00:00:00
# Average TPS: 6061.29
# ---------
# -- Neighborlist stats:
# 203 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 23 / n_neigh_avg: 9.568
# shortest rebuild period: 15
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 10 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:29 | Step 425000 / 425000 | TPS 25799.7 | ETA 00:00:00
# Average TPS: 25715.4
# ---------
# -- Neighborlist stats:
# 199 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 26 / n_neigh_avg: 10.168
# shortest rebuild period: 17
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 0 / n_max: 13 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:29 | Step 430000 / 430000 | TPS 25122.3 | ETA 00:00:00
# Average TPS: 24951.2
# ---------
# -- Neighborlist stats:
# 192 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 28 / n_neigh_avg: 10.08
# shortest rebuild period: 18
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 8 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:30 | Step 435000 / 435000 | TPS 25559.1 | ETA 00:00:00
# Average TPS: 25498.4
# ---------
# -- Neighborlist stats:
# 188 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 25 / n_neigh_avg: 9.96
# shortest rebuild period: 18
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:30 | Step 440000 / 440000 | TPS 25574.8 | ETA 00:00:00
# Average TPS: 25447
# ---------
# -- Neighborlist stats:
# 184 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 22 / n_neigh_avg: 9.808
# shortest rebuild period: 18
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# ** starting run **
# Time 00:00:30 | Step 445000 / 445000 | TPS 25287.5 | ETA 00:00:00
# Average TPS: 25212.5
# ---------
# -- Neighborlist stats:
# 170 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 25 / n_neigh_avg: 10.832
# shortest rebuild period: 18
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 5 / n_max: 29 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:31 | Step 450000 / 450000 | TPS 25321.5 | ETA 00:00:00
# Average TPS: 25244.9
# ---------
# -- Neighborlist stats:
# 172 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 26 / n_neigh_avg: 10.712
# shortest rebuild period: 19
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 7 / n_max: 26 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:31 | Step 455000 / 455000 | TPS 25047.2 | ETA 00:00:00
# Average TPS: 24914.5
# ---------
# -- Neighborlist stats:
# 169 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 32 / n_neigh_avg: 11.528
# shortest rebuild period: 20
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 9 / n_max: 32 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:32 | Step 460000 / 460000 | TPS 23963 | ETA 00:00:00
# Average TPS: 23885.5
# ---------
# -- Neighborlist stats:
# 160 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 31 / n_neigh_avg: 11.376
# shortest rebuild period: 19
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 13 / n_max: 21 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:32 | Step 465000 / 465000 | TPS 23529.6 | ETA 00:00:00
# Average TPS: 23388.3
# ---------
# -- Neighborlist stats:
# 159 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 33 / n_neigh_avg: 11.904
# shortest rebuild period: 18
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 8 / n_max: 22 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:32 | Step 470000 / 470000 | TPS 23662.9 | ETA 00:00:00
# Average TPS: 23525.5
# ---------
# -- Neighborlist stats:
# 158 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 29 / n_neigh_avg: 11.008
# shortest rebuild period: 20
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 7 / n_max: 22 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:33 | Step 475000 / 475000 | TPS 18508.4 | ETA 00:00:00
# Average TPS: 16836.3
# ---------
# -- Neighborlist stats:
# 153 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 32 / n_neigh_avg: 11.992
# shortest rebuild period: 20
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 11 / n_max: 24 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:33 | Step 480000 / 480000 | TPS 17510 | ETA 00:00:00
# Average TPS: 17435.3
# ---------
# -- Neighborlist stats:
# 153 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 32 / n_neigh_avg: 11.32
# shortest rebuild period: 21
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 10 / n_max: 19 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:34 | Step 485000 / 485000 | TPS 18693.5 | ETA 00:00:00
# Average TPS: 18443.2
# ---------
# -- Neighborlist stats:
# 152 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 36 / n_neigh_avg: 12.16
# shortest rebuild period: 22
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 5 / n_max: 25 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:34 | Step 490000 / 490000 | TPS 17164.8 | ETA 00:00:00
# Average TPS: 17058.5
# ---------
# -- Neighborlist stats:
# 145 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 30 / n_neigh_avg: 11.56
# shortest rebuild period: 24
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 10 / n_max: 28 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:35 | Step 495000 / 495000 | TPS 18694.6 | ETA 00:00:00
# Average TPS: 18587
# ---------
# -- Neighborlist stats:
# 148 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 28 / n_neigh_avg: 11.64
# shortest rebuild period: 23
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 10 / n_max: 25 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:36 | Step 500000 / 500000 | TPS 20958 | ETA 00:00:00
# Average TPS: 20846.6
# ---------
# -- Neighborlist stats:
# 149 normal updates / 50 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 33 / n_neigh_avg: 12.784
# shortest rebuild period: 22
# -- Cell list stats:
# Dimension: 2, 2, 2
# n_min    : 6 / n_max: 23 / n_avg: 15.625
# ** run complete **
# ** starting run **
# Time 00:00:46 | Step 700000 / 700000 | TPS 20842.5 | ETA 00:00:00
# Average TPS: 20840.3
# ---------
# -- Neighborlist stats:
# 7523 normal updates / 2000 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 24 / n_neigh_avg: 9.592
# shortest rebuild period: 15
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 11 / n_avg: 4.62963
# ** run complete **
# notice(2): r_buff = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.39999999999999997, 0.44999999999999996, 0.49999999999999994, 0.5499999999999999, 0.6, 0.65, 0.7, 0.75, 0.7999999999999999, 0.85, 0.9, 0.95, 1.0]
# notice(2): tps = [8017.330261092377, 11298.643484863207, 14356.800960182849, 16812.091256031337, 18933.51307548413, 20983.980829035117, 22664.635915288658, 21906.284913141582, 18410.306826173564, 24010.75681905494, 23950.374823365986, 24717.11264576917, 24990.253801017603, 19603.461187107197, 18216.661687445805, 25446.97613582578, 25212.541726756557, 23525.53697038135, 17435.3323523053, 18587.015111243283]
# notice(2): Optimal r_buff: 0.7999999999999999
# notice(2): Maximum check_period: 14
# ** starting run **
# Time 00:00:47 | Step 710000 / 710000 | TPS 19751.3 | ETA 00:00:00
# Average TPS: 19718.9
# ---------
# -- Neighborlist stats:
# 382 normal updates / 100 forced updates / 0 dangerous updates
# n_neigh_min: 0 / n_neigh_max: 27 / n_neigh_avg: 10.688
# shortest rebuild period: 17
# -- Cell list stats:
# Dimension: 3, 3, 3
# n_min    : 1 / n_max: 8 / n_avg: 4.62963
# ** run complete **
